# %%
##3odaysofpythonchallenge_1
print(3 + 5) #addition
print(5 - 3) #subtraction
print(3 * 5) #multiplication
print(3 / 5) #division
print(3 ** 5) #exponential
print(3 % 5) #modulus
print(3 // 5) #floor division

##checking datatypes
print(type(10))  #integer
print(type(10.4)) #float
print(type(1 + 3j)) #complex
print(type("Ayobami")) #string
print(type([2,4,5,6])) #list
print(type((2,4,5,6))) #tuple
print(type({'name': "Ayo"}))   #dictionary
print(type({9.6, 3.6,8.6}))  #Set
print(type(3 == 3))  #boolean
print(type(5 >= 5))  #boolean

#
print(10+2)
print(10.5+109.5)
print(1 +4j)
print("Adewale")
print([2,4,5,6])
print((2,5,6,7))
print({'class':"Group 2", 'name': "Ayobami"})
print({2,5,6})
print(5 > 10)
font
# Out:
# 8
# 2
# 15
# 0.6
# 243
# 3
# 0
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>
# <class 'bool'>
# <class 'bool'>
# 12
# 120.0
# (1+4j)
# Adewale
# [2, 4, 5, 6]
# (2, 5, 6, 7)
# {'class': 'Group 2', 'name': 'Ayobami'}
# {2, 5, 6}
# False

# %%
##3odaysofpythonchallenge_2
#using built in function

print("Hello world!")
print(len("Hello word!"))
print(float(10)) #convert int to float
print(str(20))
print(int("10")) #convert str to int
print(input("Enter your name"))


#p
print(min(20,40,20,10))
print(max(20,100,50,90))
print(min([100,5,70,2])) #it takes the list and return the min
print(max([100,5,70,2])) #it takes the list and return the max
# Out:
# Hello world!
# 11
# 10.0
# 20
# 10
# yetunde
# 10
# 100
# 2
# 100

# %%
#variables A variable name must start with a letter or the underscore character
#A variable name cannot start with a number
#A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#Variable names are case-sensitive (firstname, Firstname, FirstName and FIRSTNAME) are different variables)

first_name = "Yetunde"
country = "Nigeria"
is_married = True
language = {'name':"Ayodeji",
             'Age': 23}
skills = ['HTML','PYTHON','JAVA']

print('Firstname:', first_name)
print("County:", country)
print('language:', language)

#declaring multiple variable in one line
print(first_name,country,language,is_married)

#using the input function
name = input("what is your name")
age = input("how old are you")
print(name, age)

#Casting(converting one data type to another)
num = 10
print(float(num))
num1 = 9.89
print(int(num1))
num2 = "10"
print(int(num2))
#str to list
num3 = ("Ayobami")
print(list(num3))
#list to str
num4 = ["Ayobami", "kemi","10"]
print(str(num4))
# Out:
# Firstname: Yetunde
# County: Nigeria
# language: {'name': 'Ayodeji', 'Age': 23}
# Yetunde Nigeria {'name': 'Ayodeji', 'Age': 23} True
# Yetunde 24
# 10.0
# 9
# 10
# ['A', 'y', 'o', 'b', 'a', 'm', 'i']
# ['Ayobami', 'kemi', '10']

# %%
#Excercises Level 1(1-13)
First_name = "Michael"
Last_name = "Ajifowowe"
Full_name = "Yetunde Ajifowowe"
Country = "Nigeria"
City = "Lagos"
Age = 24
Year = 2000
is_married = False
is_True = False
is_light_on = True
cast = {'name': 'Yemi',
        'age':22}
#Excercises Level 2
print(type(First_name))
print(type(Last_name))
print(type(Full_name))
print(type(Country))
print(type(City))
print(type(Age))
print(type(Year))
print(type(is_married))
print(type(is_True))
print(type(is_light_on))
print(type(cast))
#
print(len(First_name))
print(len(First_name)-len(Last_name))
#
num_one = 5
num_two = 4
print(num_one + num_two)
print(num_one - num_two)
print(num_one * num_two)
print(num_one / num_two)
remainder = num_two % num_one
print(remainder)
floor_divison = num_one // num_two
print(floor_divison )

##Calculate the area of a circle and assign the value to a variable name of area_of_circle
rad_circle = 30
pi = 3.142
area_of_circle =  pi * rad_circle * rad_circle
print(area_of_circle)

#Take radius as user input and calculate the area.
rad_circle = float(input())
pi = 3.142
area_of_circle =  pi * rad_circle * rad_circle
print(area_of_circle)


#calculate the circumference12ii
rad_circle = 30
pi = 3.142
circum_of_circle = 2 * pi * rad_circle
print(circum_of_circle)


##13
print("First_name:", First_name,
      "Last_name:", Last_name,
      "Country:", Country,
      "Age:", Age)


##14
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'dict'>
# 7
# -2
# 9
# 1
# 20
# 1.25
# 4
# 1
# 2827.7999999999997
# 314.2
# 188.51999999999998
# First_name: Michael Last_name: Ajifowowe Country: Nigeria Age: 24

# %%
##3odaysofpythonchallenge_Day3
#operators
#Arithmetic operations in Python
print("Addition:", 1 + 2 )
print("subraction:", 3-2)
print("Division:", 10 / 2)
print("Exponentiation:", 2 ** 3)

#float
print("floating point number P:", 3.142)

#Complex
print("complex number:", 1 + 4j)
print("Multiplying complex number:", (1 + 4j) * (1 + 4j))

#
a = 5
b = 3
total = a + b
diff = a - b
division = a / b
remainder = a % b
floor_divison = a // b
exponential = a ** b
print("Total:", total)
print("Difference:", diff)
print("Division:", division)
print("Remainder:", remainder)
print("Exponential:",exponential)
# Out:
# Addition: 3
# subraction: 1
# Division: 5.0
# Exponentiation: 8
# floating point number P: 3.142
# complex number: (1+4j)
# Multiplying complex number: (-15+8j)
# Total: 8
# Difference: 2
# Division: 1.6666666666666667
# Remainder: 2
# Exponential: 125

# %%
#Example
# Calculating area of a circle
r = 10
pi = 3.142
A = pi * r**2
print("Area:", A)

#Calculating area of a rectangle
length = 10
width = 4
A = width * length
print("Area od rectangle:", A)

#Calculating a weight of an object
mass = 30
gravity = 9.8
W = mass * gravity
print("weight:", W)

#Calculate the density of a liquid
mass = 5
volume = 5
density = mass / volume
print("Density:", density)
# Out:
# Area: 314.2
# Area od rectangle: 40
# weight: 294.0
# Density: 1.0

# %%
#comparison operators
print(len("mango") == len("papwpaw"))
print(len("mango") != len("papwpaw"))
print(len("mango") > len("papwpaw"))
print(len("mango") < len("papwpaw"))

#
print("A in Abraham")
print("A not in benedict")

#Logical operators
#Unlike other programming languages python uses keywords and, or and not for logical operators. Logical operators are used to combine conditional statements:
   #and operator
print(3 > 2  and 4 > 2) 
print(4 < 1 and 4 > 1)
   #or operator
print( 4 > 2 or 2 > 4)
print(3> 2 or 2 < 3)

   #not operator
print(not 2 > 1)
# Out:
# False
# True
# False
# True
# A in Abraham
# A not in benedict
# True
# False
# True
# True
# False

# %%
#Excercises Level 3
Age = 24 #1
Height = 170  #2
var = 4 + 5j  #3
#4
base = 20
height = 10
area = 0.5 * base * height
print("Area of a triange:", area)

#5
a = 5
b = 5
c = 7
perimeter = a + b + c
print(perimeter)

#6Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))
l = 10
W = 5
area = l * W
perimeter = 2 * (l * W)
print(area)
print(perimeter)

# 7 area of a circle
pi = 3.142
r = 4
area = pi * r**2
circum = 2 * pi * r
print(area)
print(circum)

#8 Calculate the slope, x-intercept and y-intercept of y = 2x -2
x = 10
y = (2 * x) - 2
print(y)
x4 = (y + 2)/2
print(x4)

#9 find the slope and Euclidean distance between point (2, 2) and point (6,10)
x1 = 2
x2 = 6
y1 = 2
y2 = 10
m = (y2 - y1)/(x2 - x1)
print(m)

#10
print(x4 == m )

#11
x = 0
y = x ** 2 + 6*x + 9
print(y)

#12
p = "python"
d = "dragon"
print(len("python"))
print(len( "dragon"))
print(len("python") != len("dragon") )

#13 Use and operator to check if 'on' is found in both 'python' and 'dragon'
p = "python"
d = "dragon"
print("on" in p)
print("on" in d)

#14
oat = "I hope this course is not full of jargon"
print("jargon" in oat)

#15 
p = "python"
d = "dragon"
print( not"on" in p)
print(not "on" in d)

#16
p = "python"
print(float(len(p)))
print(str(len(p)))

#17 
num = 4
nom = 2
print(num / nom )

#18
a1 = 7
a2 = 3
print((a1 // a2) == int(2.7))

#19
a3 = "10"
a4 = 10
print(type(a3) == type(a4))

#20
print(int(9.8) == 10)

#21
a5 = float(input())
a6 = float(input())
print(int(a5 * a6))

#22
years = float(input())
hrs = float(input())
print(int(years * hrs))

#23
print(1, 1, 1, 1, 1)
print(2, 1, 2, 4, 8)
print(3, 1, 3, 9, 27)
print(4, 1, 4, 16, 64)
print(5, 1, 5, 25, 125)
# Out:
# Area of a triange: 100.0
# 17
# 50
# 100
# 50.272
# 25.136
# 18
# 10.0
# 2.0
# False
# 9
# 6
# 6
# False
# True
# True
# True
# False
# False
# 6.0
# 6
# 2.0
# True
# False
# False
# 100
# 100
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

# %%
#30daysofpython Day4(strings)
hour = ''' I love you michael
 you are my safe spcace
 I cant imagine doing life without you.'''
print(hour)

#String Concatenation
#We can connect strings together
name = "yetty"
name2 = "mama"
print(name + " " + name2)

#
h = "Asake"
g = "kemi"
print(h + " " + g)
print(len(h))
print(len(g))
print(len(h) > len(g))

#escape sequences in ExpandEnvironmentStrings
#\n: new line
#\t: Tab means(8 spaces)
#\\: Back slash
#\': Single quote (')
#\": Double quote (")
nam = "i love you.\nyetunde"
print(nam)
print("Days\tTopics\tName")
print("Day 1\t5\t6")
print("Day 2\t6\t6")
print("Day 3\t4\t9")
print("Day 7\t5\t6")#

#
print('yetunde is a goos girl \"Hello dear\"')
print("love you with \"hiii\"")

# string formatting
#%s - String (or any object with a string representation, like numbers)
#%d - Integers
#%f - Floating point numbers
#"%.number of digitsf" - Floating point numbers with fixed precision
##strings only 
first_name = "yetunde"
last_name = "obasi"
lang = "python"
form_string = " i am %s %s. i teach %s" %(first_name, last_name, lang)
print(form_string)

#strings and nos
rad = 10
pi = 3.14
area = pi * rad ** 2
form1_string = "the area of circle with radius %d is %.2f." %(rad, area)
print(form1_string)

##new style
first = "Seun"
last = "Ayomide"
lang = 'yoruba'
print("My name is {} {}, I am a {} girl.".format(first, last, lang))

#
a = 4
b = 4
print('{} + {} = {}'.format(a, b, a+b))
print('{} * {} = {}'.format(a,b,  a*b))
print('{} ** {} = {}'.format(a,b, a**b))
print('{} // {} = {}'.format(a,b, a//b))
print('{} / {} = {}'.format(a,b, a/b))

#
rad = 5
pi = 3.14
area = pi * rad ** 2

print("The area of the circle with radius {} is. {:.2f}.".format(rad, area))

#string interpolation
# the best is to use the formatting method
#python strings as sequence
#unpacking characters
#In programming counting starts from zero

#slicing in strings
lan = "Python"
print(lan[0])
print(lan[-1])
print(lan[-2])
print(lan[0:3])
print(lan[3:6])
print(lan[3:])
print(lan[:3])

#reverse strings
greet = "hello world"
print(greet[::-1])

#capitalize
sent = "what is your name"
print(sent.capitalize())
sent_2 = "i love you baby!"
print(sent_2.capitalize())
#counts
animal = "I dont like dog"
print(animal.count("o"))
#find
print(animal.find("o"))
#endswirh
print(animal.endswith("og"))
print(animal.endswith("on"))

#expandtabs
hou = " thirty\tdays\tin\tjuly"
print(hou.expandtabs())
# Out:
#  I love you michael
#  you are my safe spcace
#  I cant imagine doing life without you.
# yetty mama
# Asake kemi
# 5
# 4
# True
# i love you.
# yetunde
# Days	Topics	Name
# Day 1	5	6
# Day 2	6	6
# Day 3	4	9
# Day 7	5	6
# yetunde is a goos girl "Hello dear"
# love you with "hiii"
#  i am yetunde obasi. i teach python
# the area of circle with radius 10 is 314.00.
# My name is Seun Ayomide, I am a yoruba girl.
# 4 + 4 = 8
# 4 * 4 = 16
# 4 ** 4 = 256
# 4 // 4 = 1
# 4 / 4 = 1.0
# The area of the circle with radius 5 is. 78.50.
# P
# n
# o
# Pyt
# hon
# hon
# Pyt
# dlrow olleh
# What is your name
# I love you baby!
# 2
# 3
# True
# False
#  thirty days    in      july

# %%
#find
challenge = 'thirty days of python'
print(challenge.find('y'))  # 5
print(challenge.find('th')) # 0

#
challenge = 'thirty days of python'
print(challenge.rfind('y'))  # 16
print(challenge.rfind('th')) # 17

#
first_name = 'Asabeneh'
last_name = 'Yetayeh'
age = 250
job = 'teacher'
country = 'Finland'
sentence = 'I am {} {}. I am a {}. I am {} years old. I live in {}.'.format(first_name, last_name, age, job, country)
print(sentence) # I am Asabeneh Yetayeh. I am 250 years old. I am a teacher. I live in Finland.

radius = 10
pi = 3.14
area = pi * radius ** 2
result = 'The area of a circle with radius {} is {}'.format(str(radius), str(area))
print(result) # The area of a circle with radius 10 is 314

#

#
challenge = 'ThirtyDaysPython'
print(challenge.isalnum()) # True

challenge = '30DaysPython'
print(challenge.isalnum()) # True

challenge = 'thirty days of python'
print(challenge.isalnum()) # False, space is not an alphanumeric character

challenge = 'thirty days of python 2019'
print(challenge.isalnum()) # False

#
challenge = 'thirty days of python'
print(challenge.isalpha()) # False, space is once again excluded
challenge = 'ThirtyDaysPython'
print(challenge.isalpha()) # True
num = '123'
print(num.isalpha())      # False

#
web_tech = ['HTML', 'CSS', 'JavaScript', 'React']
result = ' '.join(web_tech)
print(result) # 'HTML CSS JavaScript React'
# Out:
# 5
# 0
# 16
# 17
# I am Asabeneh Yetayeh. I am a 250. I am teacher years old. I live in Finland.
# The area of a circle with radius 10 is 314.0
# True
# True
# False
# False
# False
# True
# False
# HTML CSS JavaScript React

# %%
#Excerice day4
#1
name = "Thirty", "Days", "of", "Python"
print(" ".join(name))

#2
name = "Coding", "for", "All"
print(" ".join(name))

#3-13
company = "Coding for All"
print(company)
print(len(company))
print(company.upper())
print(company.lower())
print(company.capitalize())
print(company.title())
print(company.swapcase())
print(company.find("Coding"))
print(company.replace("Coding", "Python"))
print(company.replace("Python for everyone", "Python for All"))
print(company.split(", "))

#14
name = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print(name.split(","))

#15 What is the character at index 0 in the string Coding For All."C"

#16 What is the last index of the string Coding For All.
13
# 17  What character is at index 10 in "Coding For All" string "SPACING"

# 18 Create an acronym or an abbreviation for the name 'Python For Everyone
name = "Python for everyone" #PFE

#19 Create an acronym or an abbreviation for the name 'Coding For All'."CFA"
#20 Use index to determine the position of the first occurrence of C in Coding For All
print(company.index("C"))
#21Use index to determine the position of the first occurrence of F in Coding For All.
print(company.index("f"))
#22
print(company.rfind("l"))
#23 first occurence of before
host = "You cannot end a sentence with because because because is a conjunction"
print(host.find("because"))

#24 last occurence of because
print(host.rindex("because"))

#25
print(host.strip("be"))#not sure

#26
#27
#28-#29
print(company.startswith("Coding"))
print(company.endswith("coding"))

#30
name = '   Coding For All      '  
print(name.replace(" ", " "))

#31Which one of the following variables return True when we use 
# the method isidentifier():
#30DaysOfPython
#thirty_days_of_python
name = "30DaysOfPython" #FALSE
name2 = "thirty_days_of_python" #TRUE
print(name.isidentifier())
print(name2.isidentifier())

#32
list =  ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print("#".join(list))

#33
name = "I am enjoying this challenge"

#34
print("Name\tAge\tCountry\tCity")
print("Ayo\t25\tkorea\tDaegu")

#35
radius = 10
area = 3.14 * radius ** 2
print(area)

#36
a =  8
b = 6
print("{} + {} = {}".format(a, b, a+b))
print("{} - {} = {}".format(a, b, a-b))
print("{} * {} = {}".format(a, b, a*b))
print("{} / {} = {}".format(a, b, a/b))
print("{} // {} = {}".format(a, b, a//b))
print("{} ** {} = {}".format(a, b, a**b))
# Out:
# Thirty Days of Python
# Coding for All
# Coding for All
# 14
# CODING FOR ALL
# coding for all
# Coding for all
# Coding For All
# cODING FOR aLL
# 0
# Python for All
# Coding for All
# ['Coding for All']
# ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']
# 0
# 7
# 13
# 31
# 47
# You cannot end a sentence with because because because is a conjunction
# True
# False
#    Coding For All
# False
# True
# Django#Flask#Bottle#Pyramid#Falcon
# Name	Age	Country	City
# Ayo	25	korea	Daegu
# 314.0
# 8 + 6 = 14
# 8 - 6 = 2
# 8 * 6 = 48
# 8 / 6 = 1.3333333333333333
# 8 // 6 = 1
# 8 ** 6 = 262144
