# %%
#Declearing Variable

company_name = "XTRARITE SUPERSTORES LTD"
company_address = "1 BABS OGUNWOLE STREET,OFF OLAYIWOLA JUNCTION NEW OKO OBA,LAGOS"
TEl, number  = "TEl",   836691177
time, clock, PM = 8, 15, "PM"
INVOICE = "Cash Sales Invoice"

#RECEIPT DETAILS
party, name = "Party", "WALK IN CUSTOMER"
Date, number = "Date", "25-11-2022"
Cash_ReceiptNo, Number = "CashReceipt", "2022/97632"
Attendant = "ATTENDANT"
CASHIER, NAME = "CASHIER", "REJOICE"

#Store information
Store_info = "Goods sold cannot be Returned"

#store message
Store_message = "Thanks For Your Patronage"

#print description
DE_1, Qty, Price, Amount = "GO RITE SUPER LOAF", 1, 800.00, 800.00

Amount_Tendered, Discount, Change_Given = 0.00, 0.00, 0.00

#printing now

print("{}" .format(company_name))
print("{}" .format(company_address))
print("{}:   {}" . format(TEl,    number))
print("{}:{}  {}".format(time,  clock, PM))
print("{}" .format(INVOICE))


#Print receipt details
print("{}:   {}" .format(party, name))
print("{}:   {}" .format(Date,   number))
print("{}:   {}" .format(Cash_ReceiptNo, Number))
print("{}:" .format(Attendant))
print("{}:   {}" .format(CASHIER, NAME))

#print the dash bar
print("-" * 50)
#print description
print(" Description         Qty         Price      Amount")
print("-" * 50)
print("{}     {}         {}      {}"  .format(DE_1, Qty, Price, Amount))
print("Amount_Tendered     Discount    Change_Given")

print("{}                 {}          {}" .format(Amount_Tendered, Discount, Change_Given))
print("    {}" .format(Store_info))
print("{}" .format(Store_message))
# Out:
# XTRARITE SUPERSTORES LTD
# 1 BABS OGUNWOLE STREET,OFF OLAYIWOLA JUNCTION NEW OKO OBA,LAGOS
# TEl:   25-11-2022
# 8:15  PM
# Cash Sales Invoice
# Party:   WALK IN CUSTOMER
# Date:   25-11-2022
# CashReceipt:   2022/97632
# ATTENDANT:
# CASHIER:   REJOICE
# --------------------------------------------------
#  Description         Qty         Price      Amount
# --------------------------------------------------
# GO RITE SUPER LOAF     1         800.0      800.0
# Amount_Tendered     Discount    Change_Given
# 0.0                 0.0          0.0
#     Goods sold cannot be Returned
# Thanks For Your Patronage
