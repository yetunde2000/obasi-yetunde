# %%
# Python Error Types
#When we write code it is common that we make a typo or some other common error. If our code fails to run, the Python interpreter will 
#display a message, containing feedback with information on where the problem occurs and the type of an error.

# it helps to know the different types of erros that can occur in Python.


# Syntax Errors
print 'hello world'
#
print('hello world')
# Out:
#   Cell In[11], line 9
#     print 'hello world'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#NameError
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 #NameError
# ----> 2 print(name)
#
# NameError: name 'name' is not defined

# %%
# IndexError
ove = [1,2,3,4,5]
print(ove[7]) # because the list has only 5 elements
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 # IndexError
#       2 ove = [1,2,3,4,5]
# ----> 3 print(ove[7])
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
import maths # 's' is added to "math" that is why it is module not found error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 2
#       1 # ModuleNotFoundError
# ----> 2 import maths
#
# ModuleNotFoundError: No module named 'maths'

# %%
import numpys as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import numpys as np
#
# ModuleNotFoundError: No module named 'numpys'

# %%
# AttributeError
import math
math.PI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 3
#       1 # AttributeError
#       2 import math
# ----> 3 math.PI
#
# AttributeError: module 'math' has no attribute 'PI'

# %%
import math
math.pi
math.sqrt(25)
# Out:
# 5.0

# %%
users = {'name':'Asab', 'age':250, 'country':'Finland'}
users['county']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 users = {'name':'Asab', 'age':250, 'country':'Finland'}
# ----> 2 users['county']
#
# KeyError: 'county'

# %%
#TypeError
print('2' + 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 #TypeError
# ----> 2 print('2' + 2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#ImportError
from math import power
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 2
#       1 #ImportError
# ----> 2 from math import power
#
# ImportError: cannot import name 'power' from 'math' (unknown location)

# %%
#ValueError
int('12a')ss
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 #ValueError
# ----> 2 int('12a')
#
# ValueError: invalid literal for int() with base 10: '12a'

# %%
#ZeroDivisionError
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[41], line 2
#       1 #ZeroDivisionError
# ----> 2 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
print(100/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(100/0)
#
# ZeroDivisionError: division by zero
