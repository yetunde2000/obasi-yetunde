# %%
#30daysPythonchallenge_DAY11
#functions
#it a reuseable code for a certain task(it uses 'def' to declare a function)
# syntax
# Declaring a function
#def function_name():
    #codes
    #codes
# Calling a function
#function_name()

def full_name():
    first_name = 'yetty'
    last_name = 'obasi'
    space = ' '
    full = first_name + space + last_name
    print(full)
full_name()

#numbers
def number():
    num1 = 1
    num2 = 5
    print(num1 + num2)
number()
#
def numbers(num1, num2): # declaring a function
    print(3 + 4)
numbers(3,4)  # calling a function
# Out:
# yetty obasi
# 6
# 7

# %%
#Return values
def full_name():
    name1 = 'funmi'
    name2 = 'Ayo'
    full = name1 + " " + name2
    return full
print(full_name())

#add
def numbers():
    a = 4
    b = 6
    add = a + b
    return add
print(numbers())

#Functions and parameters in a function we can pass different data types(number, string, boolean, list, tuple, dictionary or set) as a parameter
def full_name(name1, name2):
    message = name1 + " and " + name2 + " " +',what are you doing?'
    return message
print(full_name('kemi', 'seyi'))
#
def area(pi, r):
    area_of_circle = pi * r **2
    return area_of_circle
print(area(2,3))
#
def summer(n):
    sum = 0
    for i in range(n+1):
       sum += i 
    print(sum)
print(summer(5))
# Out:
# funmi Ayo
# 10
# kemi and seyi ,what are you doing?
# 18
# 15
# None

# %%
#Passing Arguments with Key and Value
#If we pass the arguments with key and value, the order of the arguments does not matter.

def num(num1, num3):
    naumber = num1 + " " + num3
    return naumber
print(num(num3 = 'kemi', num1 = 'seyi'))

#
def fullname(first):
    return(first)
print(fullname('kemi'))

#
def fullname(first, last):
    return (first, last)
print(fullname(first ='Obasi', last = 'Yetunde'))

# return boolean
def is_even(n):
    if n % 2 == 0:
        print('even')
        return True
    return False
print(is_even(10))
print(is_even(7))

# return list
def lst(n):
    eve = []
    for i in range(n):
        if i % 2 == 0:
            eve.append(i)
    return eve
print(lst(10))

# functions with default parameters
def funct(name = 'kemi'):
    stu = name + " " + 'I love you so much'
    return stu
print(funct())
print(funct('femi'))
print(funct('Iyanu'))

# Returning boolean
def funct(n):
    if n % 2 == 0:
        print('even')
        return True
    return False
print(funct(10))
print(funct(7))

#
def cal(current, old = 67):
    age = current - old
    return age
print(cal(current = 70))

# Arbitrary Number of Arguments
def funct(*sum):
    total = 0
    for i in sum:
        total += i
    return total
print(funct(2, 3, 4, 5))

#
def funct(team, *sum):
    print(team)
    for i in sum:
        print(i)
print(funct('Team-1','Asabeneh','Brook','David','Eyob'))
# Out:
# seyi kemi
# kemi
# ('Obasi', 'Yetunde')
# even
# True
# False
# [0, 2, 4, 6, 8]
# kemi I love you so much
# femi I love you so much
# Iyanu I love you so much
# even
# True
# False
# 3
# 14
# Team-1
# Asabeneh
# Brook
# David
# Eyob
# None

# %%
#Excercise~day11~level 1
#1
def fun(num1, num2):
    sum = num1 + num2
    return sum
print(fun(5,5))
#2
def area(pi,r,):
    area_of_circle = pi* r**2
    return area_of_circle
print(area(2,2))
#3
def add_all_numbers(*args):
    sum = 0
    for i in args:
        sum += i
    return sum
print(add_all_numbers(2, 4, 6, 8))
#4
def func(fah):
    fa = (fah - 32) * 5 / 9 
    return fa
fahren = 40
C = func(fahren)
print(f"{fahren}°F = {C}°C")

#5
def check_season(Jan,June,Nov):
    return(Jan,June,Nov)
print(check_season('Spring', 'Summer', 'Autum'))
#6
def set(m,x,b):
    y = m*x + b
    return y
print(set(2,2,2))

#7
def quadratic(a,x,b,c):
    F = a* x**2 + b*x + c 
    return F
print(quadratic(2,2,2,2))

#8
def print_list():
    lst = [2,4,5,6]
    return lst
print(print_list())
#9
def funct(name = [], name2 = []):
    for i in name[::-1]:
        print(i)
    for j in name2[::-1]:
        print(j)
num = [1, 2, 3, 5]
nam = ['a', 'b', 'c', 'd']
print(funct(num))
print(funct(nam))

#10
#def kain():
    #yes = ['kemi', 'kemo', 'kamsi', 'kay']
    #yes.capitalize()
    #return yes
#print(kain())

#11a
def add():
   name = ['kemi', 'kemo', 'kamsi', 'kay']
   name.append('funmi')
   return name
print(add())
#11b
def add():
    num = [2,4,5,6]
    num.append(7)
    return num
print(add())
    
#12a  remove item    
def rem():
   name = ['kemi', 'kemo', 'kamsi', 'kay']
   name.pop(2)
   return name
print(rem())
#12b 
def rem():
    num = [2,4,5,6]
    num.pop(3)
    return num
print(rem())  
   
#13
def summer():
    num = [2,4,5,6]
    return num
print(summer())

#14
def even(n):
    sum = 0
    for i in range(n):
        if i % 2 == 0:
            sum += i
   
    print(sum)
print(even(10))

#15
def odd(n):
    sum = 0
    for i in range(n):
        if i % 2 != 0:
            sum += i
    print(sum)
print(odd(10))
# Out:
# 10
# 8
# 20
# 40°F = 4.444444444444445°C
# ('Spring', 'Summer', 'Autum')
# 6
# 14
# [2, 4, 5, 6]
# 5
# 3
# 2
# 1
# None
# d
# c
# b
# a
# None
# ['kemi', 'kemo', 'kamsi', 'kay', 'funmi']
# [2, 4, 5, 6, 7]
# ['kemi', 'kemo', 'kay']
# [2, 4, 5]
# [2, 4, 5, 6]
# 20
# None
# 25
# None

# %%
#excercise level 2
#1
def num(n):
    count = 0
    current = 0
    while n >= current:
        if (current % 2) == 0:
            count += 1
            current += 1
        else:
            current += 1
    return count
      

print(num(100))

def num(n):
    count = 0
    current = 0
    while n >= current:
        if (current % 2) != 0:
            count += 1
            current += 1
        else:
            current += 1
    return count
      
print(num(100))   
#2
import math
def cal_factorial(x):
    return(math.factorial(x))
num = 5
f = cal_factorial(num)
print( f)
#3 Call your function is_empty, 
# it takes a parameter and it checks if it is empty or not
def is_empty():
    my = []
    if not my == "":
        print("True")
    else:
        print('False')
print(is_empty())
    
#3
def list():
    list1 = [2,4,5,6,7]
    n = len(list1)
    get = sum(list1)
    mean = get/ n
    return mean
    
print(list())
def list():
    list2 = [1,2,3,4,5]
    m = len(list2)
    gat = sum(list2)
    meen = gat/ m
    return meen
print(list())
# Out:
# 51
# 50
# 120
# True
# None
# 4.8
# 3.0

# %%
#excercise level 3
#1
def funct(n):
    if n / 5 == 1:
      print('even')
      return True
    
    else:
      print("no")
      return False
  
print(funct(5))

#
#def funct(m):
  #if m.isidentifier():
    #print(type(m))
    #return True
  #else:
    #print("no")
    #return False
#print(funct([2,4,5,6]))

#3 I am not sure of this..i think i got it
def funct(m):
  she = iter(m)
  first = type(next(she))
  if all ((type(x) is first)):
    for x in m:
      return first
    else:
      False
# 4 Write a function which check if provided variable is a valid python variable
"X".isidentifier()
# Out:
# even
# True
# True

# %%
# Python3 code to demonstrate the
# random generation of string id's
 
import random
import string
 
# Generate a random string
# with 32 characters.
random = ''.join([random.choice(string.ascii_letters
            + string.digits) for n in range(32)])
 
# print the random
# string of length 32
print (random)
# Out:
# 6dEqyIsj56dGggO0B4iJlnHWzGI32iAY

# %%
import random
import string
ran2 = input(" ").join([random.choice(string.ascii_letters
            + string.digits) for n in range(3)])
ran = input(" ").join([random.choice(string.ascii_letters
            + string.digits) for n in range(3)])
print(ran2)
print(ran)
# Out:
# h5x5A
# q5754

# %%
import random 
def rgb_color_gen():
      
     for x in range(3):
      print(random.randint(0, 255))
print(rgb_color_gen())
# Out:
# 136
# 40
# 15
# None

# %%
import random
r = lambda: random.randint(0,255)
print('#%02X%02X%02X' % (r(),r(),r()))
# Out:
# #8CA4D7
