# %%
#30daysPythonChallenge
#day 12_ modules
#A module is a file containing a set of codes or a set of functions which can be included to an application. 

def gen(first, last):
    return first + " " + last
print(gen('YETUNDE', 'OBASI'))
# Out:
# YETUNDE OBASI

# %%
#Importing a module
import mymodule
print(mymodule.)
