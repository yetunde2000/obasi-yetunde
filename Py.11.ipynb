# %%
#30daysPythonChallenge: Day 16
# Python Data Time: Python has got datetime module to handle date and time.

import datetime
print(dir(datetime))
print(datetime.datetime.now())

#
from datetime import datetime
now = datetime.now()
day = now.day
month = now.month
year = now.year
hour = now.hour
minute = now.minute
second = now.second
print(f'{day}/{month}/{year}, {hour}:{minute}:{second}')

#
from datetime import datetime
now = datetime(2024, 1, 1)
day = now.day
month = now.month
year = now.year
hour = now.hour
minute = now.minute
second = now.second
print(f'{day}/{month}/{year}, {hour}:{minute}:{second}')

##
#Using date from datetime
from datetime import date
d = date(2020, 1,1)
print(d)
print('Curremt date:', d.today())
# date object of today's date
today = date.today()
print('Current year:', today.year)
print('Current month:', today.month)
print('Current day:', today.day)

##
from datetime import time
a = time()
print('a =', a)
b = time(10, 30, 50)
print("b =", b)

# differenece between two points in time
today = date(year = 2019, month = 12, day = 15)
new = date(year = 2020, month = 1, day = 1)
diff = new- today
print("Difference:", diff)

# differenece between two points in timedelta
from datetime import datetime, timedelta
t1 = timedelta(weeks = 14, days = 6, hours = 24, seconds = 60)
t2 = timedelta(days = 4, hours = 5, seconds = 20 )
dif = t1-t2
print(dif)
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']
# 2025-01-08 17:09:01.695135
# 8/1/2025, 17:9:1
# 1/1/2024, 0:0:0
# 2020-01-01
# Curremt date: 2025-01-08
# Current year: 2025
# Current month: 1
# Current day: 8
# a = 00:00:00
# b = 10:30:50
# Difference: 17 days, 0:00:00
# 100 days, 19:00:40

# %%
# Exercises: Day 16
#1
from datetime import datetime
now = datetime.now()
day = now.day
month = now.month
year = now.year
hour = now.year
minute = now.minute
print(f'{day}/{month}/{year}, {hour}:{minute}')

#2
from datetime import datetime
now = datetime.now()
t = now.strftime('%H:%M:%S')
print(t)
timeone = now.strftime('%d/%m/%Y, %H:%M:%S')
print('timeone:', timeone)

#3
from datetime import time

# 4
from datetime import datetime, timedelta
today = date(year = 2024, month = 1, day = 1)
new = date(year = 2024, month = 1, day = 8)
diff = new- today
print("The difference is :", diff)

#5
from datetime import datetime, timedelta
today = date(year = 1970, month = 1, day = 1)
new = date(year = 2024, month = 1, day = 8)
diff = new- today
print("The difference is :", diff)

#Note: This can be used for time series analysis and timesetp of any appliation
# Out:
# 8/1/2025, 2025:42
# 17:42:03
# timeone: 08/01/2025, 17:42:03
# The difference is : 7 days, 0:00:00
# The difference is : 19730 days, 0:00:00
